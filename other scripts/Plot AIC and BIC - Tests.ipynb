# %%
import numpy as np
import os
from multiprocessing import Pool
from multiprocessing import cpu_count
import pandas as pd
from sklearn.mixture import GaussianMixture
import pickle
import traceback

import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
saved_AIC = './Mt_Bolton_altitude_4_12.aic'
saved_BIC = './Mt_Bolton_altitude_4_12.bic'

# %%
AIC = pickle.load(open(saved_AIC, 'rb'))
BIC = pickle.load(open(saved_BIC, 'rb'))

# %%
AIC = pickle.load(open(saved_AIC, 'rb'))
BIC = pickle.load(open(saved_BIC, 'rb'))
plt.plot([AIC[n][1] for n in range(len(AIC))], [AIC[n][0] for n in range(len(AIC))], label='AIC')
plt.plot([BIC[n][1] for n in range(len(AIC))], [BIC[n][0] for n in range(len(AIC))], label='BIC')
plt.legend(loc='best')
plt.xlabel('No of Components');

# %% [markdown]
# # Old way

# %%
# %%time
plt.plot([model.n_components for model in models], [m.bic(df.values) for m in models], label='BIC')
plt.plot([model.n_components for model in models], [m.aic(df.values) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');
